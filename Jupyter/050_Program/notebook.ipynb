# %% [markdown]
# # Altair\nProgram 050

# %%
import numpy as np\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport seaborn as sns

# %% [markdown]
# This is a Jupyter notebook demonstrating altair.

# %%
# Implement the program logic here...
